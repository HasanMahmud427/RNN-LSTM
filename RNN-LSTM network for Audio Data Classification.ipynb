# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATASET_PATH = "data.json"

def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)
        
        
    # convert the lists into numpy arrays
    x = np.array(data["mfcc"])    # x is input
    y = np.array(data["labels"])  # y is target
    
    return x, y


def prepare_datasets(test_size, validation_size):
    # load data
    x, y = load_data(DATASET_PATH)
    
    # create train/test split
    x_train, x_test, y_train, y_test = train_test_split(x,
                                                        y,
                                                        test_size = test_size)
    
    # create train/ validation split
    x_train, x_validation, y_train, y_validation = train_test_split(x_train,
                                                                    y_train,
                                                                    test_size = validation_size)
     
    return x_train, x_validation, x_test, y_train, y_validation, y_test




def build_model(input_shape):
    
    # create RNN-LSTM model
    model = keras.Sequential()
    
    # 2 LSTM layers
    model.add(keras.layers.LSTM(64, input_shape = input_shape, return_sequences = True))
    model.add(keras.layers.LSTM(64))
    
    
    # dense Layer
    
    model.add(keras.layers.Dense(64, activation = 'relu'))
    model.add(keras.layers.Dropout(0.3))
              
              
    
    
    
    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))
    
    return model


def predict(model, X, Y):
    X = X[np.newaxis, ...]
    # prediction = [[0.1, 0.2,.....]]( normalized value form softmax)
    prediction = model.predict(X) # X -> (1, 130, 13, 1)
    
    # extract index with max value
    predicted_index = np.argmax(prediction, axis=1) # [4]
    print("Expected index : {}, Predicted index : {}".format(Y, predicted_index))
    
    
def plot_history(history):
    
    fig, axs = plt.subplots(2)
    
    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")
    
    # create error subplot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test reeor")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")
    
    plt.show()
    
    

if __name__ == "__main__":
    
    # create train, validation and test sets
    x_train, x_validation, x_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2) # test set and then validation
    
    # build the CNN net
    input_shape = (x_train.shape[1], x_train.shape[2]) # 130, 13 
    model = build_model(input_shape)
    
    
    # compile the network
    
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer = optimizer,
                 loss="sparse_categorical_crossentropy",
                 metrics=['accuracy'])
    
    model.summary()
    
    # train the CNN
    history = model.fit(x_train, y_train, validation_data=(x_validation, y_validation),
             batch_size=32, epochs=30)
    
    # plot accuracy / error for training and validation
    # plot_history(history)
    
    # evaluate the CNN on the test set
    test_error, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
    print("Accuracy on test set is : {}".format(test_accuracy))
    
    
    # make the prediction on a sample
    
    X = x_test[0]
    Y = y_test[0]
    
    predict(model, X, Y)
    
    
    plot_history(history)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, 130, 64)           19968
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                650
# =================================================================
# Total params: 57,802
# Trainable params: 57,802
# Non-trainable params: 0
# _________________________________________________________________
# Train on 599 samples, validate on 150 samples
# Epoch 1/30
# 599/599 [==============================] - 9s 14ms/sample - loss: 2.2827 - accuracy: 0.1386 - val_loss: 2.2831 - val_accuracy: 0.1467
# Epoch 2/30
# 599/599 [==============================] - 4s 6ms/sample - loss: 2.2356 - accuracy: 0.1569 - val_loss: 2.2466 - val_accuracy: 0.1933
# Epoch 3/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 2.1946 - accuracy: 0.1886 - val_loss: 2.2122 - val_accuracy: 0.2133
# Epoch 4/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 2.1584 - accuracy: 0.2304 - val_loss: 2.1760 - val_accuracy: 0.2333
# Epoch 5/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 2.1163 - accuracy: 0.2571 - val_loss: 2.1346 - val_accuracy: 0.2733
# Epoch 6/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 2.0826 - accuracy: 0.2855 - val_loss: 2.0939 - val_accuracy: 0.3133
# Epoch 7/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 2.0108 - accuracy: 0.3406 - val_loss: 2.0524 - val_accuracy: 0.3400
# Epoch 8/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.9776 - accuracy: 0.3222 - val_loss: 2.0119 - val_accuracy: 0.3400
# Epoch 9/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.9068 - accuracy: 0.3840 - val_loss: 1.9665 - val_accuracy: 0.3600
# Epoch 10/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.8848 - accuracy: 0.3806 - val_loss: 1.9173 - val_accuracy: 0.3733
# Epoch 11/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.8339 - accuracy: 0.3723 - val_loss: 1.8659 - val_accuracy: 0.4000
# Epoch 12/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.7772 - accuracy: 0.4057 - val_loss: 1.8162 - val_accuracy: 0.4267
# Epoch 13/30
# 599/599 [==============================] - 5s 8ms/sample - loss: 1.7169 - accuracy: 0.4341 - val_loss: 1.7644 - val_accuracy: 0.4533
# Epoch 14/30
# 599/599 [==============================] - 5s 8ms/sample - loss: 1.6508 - accuracy: 0.4908 - val_loss: 1.7154 - val_accuracy: 0.4867
# Epoch 15/30
# 599/599 [==============================] - 5s 8ms/sample - loss: 1.6238 - accuracy: 0.4775 - val_loss: 1.6647 - val_accuracy: 0.5133
# Epoch 16/30
# 599/599 [==============================] - 5s 8ms/sample - loss: 1.5376 - accuracy: 0.5042 - val_loss: 1.6054 - val_accuracy: 0.5133
# Epoch 17/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.4694 - accuracy: 0.5476 - val_loss: 1.5528 - val_accuracy: 0.5400
# Epoch 18/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.4383 - accuracy: 0.5459 - val_loss: 1.4928 - val_accuracy: 0.5867
# Epoch 19/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.3469 - accuracy: 0.5993 - val_loss: 1.4292 - val_accuracy: 0.6000
# Epoch 20/30
# 599/599 [==============================] - 5s 8ms/sample - loss: 1.2957 - accuracy: 0.5960 - val_loss: 1.3500 - val_accuracy: 0.6400
# Epoch 21/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.2381 - accuracy: 0.6177 - val_loss: 1.2937 - val_accuracy: 0.6533
# Epoch 22/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.1299 - accuracy: 0.6711 - val_loss: 1.2487 - val_accuracy: 0.6333
# Epoch 23/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.0783 - accuracy: 0.6962 - val_loss: 1.2118 - val_accuracy: 0.6667
# Epoch 24/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 1.0316 - accuracy: 0.6912 - val_loss: 1.1563 - val_accuracy: 0.6733
# Epoch 25/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 0.9947 - accuracy: 0.7028 - val_loss: 1.1498 - val_accuracy: 0.6600
# Epoch 26/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 0.9801 - accuracy: 0.7062 - val_loss: 1.0832 - val_accuracy: 0.6733
# Epoch 27/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 0.9201 - accuracy: 0.7479 - val_loss: 1.0431 - val_accuracy: 0.6733
# Epoch 28/30
# 599/599 [==============================] - 5s 8ms/sample - loss: 0.8684 - accuracy: 0.7446 - val_loss: 1.0250 - val_accuracy: 0.6800
# Epoch 29/30
# 599/599 [==============================] - 4s 7ms/sample - loss: 0.8575 - accuracy: 0.7379 - val_loss: 1.0207 - val_accuracy: 0.6933
# Epoch 30/30
# 599/599 [==============================] - 5s 8ms/sample - loss: 0.8073 - accuracy: 0.7863 - val_loss: 1.0158 - val_accuracy: 0.6733
# 250/1 - 0s - loss: 0.9479 - accuracy: 0.6840
# Accuracy on test set is : 0.6840000152587891
# Expected index : 0, Predicted index : [0]
